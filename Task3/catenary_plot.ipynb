# %%
#3.22

import math
import numpy as np
import matplotlib.pyplot as plt

#x = range(-5,6)
#y = []
#for n in x:
    #y += [math.cosh(n)]

x = np.arange(-5,6)
y = np.cosh(x)

plt.scatter(x,y,label='y=coshx')
plt.title('Catenary')
plt.grid()
plt.xlabel('X values')
plt.ylabel('Y values - cosh function')
plt.legend()
plt.show()

# %% [markdown]
# ![Screenshot_20260227_103720.png](attachment:Screenshot_20260227_103720.png)
