# %% [markdown]
# Answers for Week 1
#
# * Name: Tamara Balvin
# * Username: tbalvin
# * Student s-number: S6217451
# * Group (AS1, etc.): AS1

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %%
x=6
for i in range(5):
    x*=(5-i)
print(x)
# Out:
# 720

# %%
from scipy.constants import c, h
freq = 2.42e28
energy = h * c / freq
print(energy)
# Out:
# 8.208453955160862e-54

# %%
from scipy.constants import G
m1 = 7.342e22
m2 = 5.9722e24
r = 385000600
force = G * m1 * m2 / (r**2)
print("force: ", force, 'N')
# Out:
# force:  1.974384051807571e+20 N

# %%
from scipy.constants import G, pi, au
period = 365*24*60*60
total_mass = (4*(pi**2)*(au**3))/(G*(period**2))
print(total_mass)
# Out:
# 1.9912098654808826e+30

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
# Out:
# 103.142857142857143

# %% [markdown]
# 1.10
# ![Screenshot%202026-02-11%20152808.png](attachment:Screenshot%202026-02-11%20152808.png)
#
# 1.15
# 1. /Users/users/tbalvin/Downloads
# 2. . - /Downloads
# 3. .. - ~ or /Users/users/tbalvin
#
# 1.16
# cd ~/Desktop
#
# 1.19
# 1. lists file with a number from 0-9 before a dot and the letter c or o after the dot
# 2. gives range of characters wanted
# 3. lists file with ending .co

# %% [markdown]
# 1.11
# ![Screenshot_20260211_153304.png](attachment:Screenshot_20260211_153304.png)

# %% [markdown]
# 1.12
# ![Screenshot_20260211_160333.png](attachment:Screenshot_20260211_160333.png)
